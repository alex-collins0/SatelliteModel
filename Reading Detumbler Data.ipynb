# %%
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df = df.set_index(keys='time', drop=True)
# df = df.loc[:20]

# %%
df.index
# Out:
# Float64Index([   0.0,   0.01,   0.11,   0.21,   0.31,   0.41,   0.51,   0.61,
#                 0.71,   0.81,
#               ...
#                99.11,  99.21,  99.31,  99.41,  99.51,  99.61,  99.71,  99.81,
#                99.91, 100.01],
#              dtype='float64', name='time', length=1002)

# %%
ax = df.plot(y='moments_1')
df.plot(y='moments_2', ax=ax)
df.plot(y='moments_3', ax=ax, grid=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
ax = df.plot(y='w_1')
df.plot(y='w_2', ax=ax)
df.plot(y='w_3', ax=ax, grid=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.plot(x='roll', y='pitch')
# Out:
# <AxesSubplot:xlabel='roll'>

# %%
ax = df.plot(y='roll')
df.plot(y='pitch', ax=ax)
df.plot(y='yaw', ax=ax, grid=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.angular_moment.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.rotational_kinetic_energy.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.moments_3.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
ax = (df.moments_3 / 20).plot()
ax = df.plot(y='control_signal_1', ax=ax)
